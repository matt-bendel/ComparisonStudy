# %%
import sys
sys.path.append('/home/liu.6221/PnP_fastMRI-master _Liu')
import logging
import pathlib
import random
import shutil
import time
import os
import h5py
import numpy as np
import torch
import torchvision
from tensorboardX import SummaryWriter
from torch.nn import functional as F
from torch.utils.data import DataLoader
# from common.args import Args
from common.subsample import MaskFunc
from data import transforms
from data.mri_data import SelectiveSliceData
from models.unet.unet_model import UnetModel
from models.PnP.dncnn import DnCNN

from data.multicoil_sim import random_map

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
data_root = '/storage/fastMRI_brain/data/Sizhuo_preprocessed_data/training'
files = list(pathlib.Path(data_root).iterdir())
files = files[1:2]
keep_slices_o = []
keep_slices_i = []
for fname in sorted(files):
    with h5py.File(fname, 'r') as data:
        pnp_o = data['pnp_truth'].value
        random_slices = pnp_o[:,:,round(random.uniform(0,5))]
        print(abs(np.real(random_slices)).max())
        random_slices = random_slices/abs(np.real(random_slices)).max()
        print(abs(np.real(random_slices)).max())
        print(abs(np.imag(random_slices)).max())
        sigma = np.linalg.norm(random_slices)/np.sqrt(random_slices.size)/(10**(20/20))/np.sqrt(2)
        print(sigma)
        sigma = 0.037
        data_out = torch.from_numpy(np.stack((random_slices.real, random_slices.imag), axis=-1)).float()
                
#                 for i in range()
#                 data_out = transforms.complex_random_crop(data_out,(64,64))
    
        data_in = data_out + sigma*torch.randn(data_out.size())
#         data_in_max = torch.max(torch.abs(data_in[:,:,0]))
#         data_out = data_out / data_in_max
#         data_in = data_in / data_in_max
        
        error = ((data_in - data_out)**2).mean()
        print(error)
        

        
#                 self.keep_slices_o.append(data_out.permute(2,0,1))
#                 self.keep_slices_i.append(data_in.permute(2,0,1))

# %%
o = (data_out[:,:,0]).numpy()+1j*(data_out[:,:,1]).numpy()
print(o.shape)
i = (data_in[:,:,0]).numpy()+1j*(data_in[:,:,1]).numpy()
import matplotlib.pyplot as plt
# print(np.linalg.norm(i))
# print(np.linalg.norm(o))
plt.imshow(abs(o), cmap = 'gray',vmin=0, vmax=1)
# plt.imshow(abs(i), cmap = 'gray',vmin=0, vmax=1)

# %%
class create_datasets():
    def __init__(self):
        data_root = '/storage/fastMRI_brain/data/Sizhuo_preprocessed_data/training'
        files = list(pathlib.Path(data_root).iterdir())
#         files = files[0:1]
        self.keep_slices_o = []
        self.keep_slices_i = []
        for fname in sorted(files):
            with h5py.File(fname, 'r') as data:
                pnp_o = data['pnp_truth'].value
                random_slices = pnp_o[:,:,round(random.uniform(0,5))]
                random_slices = random_slices/abs(np.real(random_slices)).max()
#                 sigma = np.linalg.norm(random_slices)/np.sqrt(random_slices.size)/(10**(14/20))/np.sqrt(2)
                sigma = 0.015
                data_out = torch.from_numpy(np.stack((random_slices.real, random_slices.imag), axis=-1)).float()
                data_in = data_out + sigma*torch.randn(data_out.size())
                data_in_max = torch.max(torch.abs(data_in[:,:,0]))
                data_out = data_out / data_in_max
                data_in = data_in / data_in_max 
                
                for i in range(144):
                    data_out,data_in = transforms.complex_random_crop(data_out,data_in,(64,64))
    

#                     self.keep_slices_o.append(data_in.permute(2,0,1))
#                     self.keep_slices_i.append(data_in.permute(2,0,1))        
                    self.keep_slices_o.append(data_out.permute(2,0,1))
                    self.keep_slices_i.append(data_in.permute(2,0,1))
    def __len__(self):
        return len(self.keep_slices_o)
    def __getitem__(self, index):
        outp = self.keep_slices_o[index]
        inp = self.keep_slices_i[index]
        return inp, outp

# %%
def create_data_loaders():
#     dev_data, train_data = create_datasets(args)
#     display_data = [dev_data[i] for i in range(0, len(dev_data), len(dev_data) // 16)]

    train_loader = DataLoader(
        create_datasets(),
        batch_size=32,
        shuffle=True,
        num_workers=16,
        pin_memory=True,
    )

    return train_loader

# %%
def main():

    writer = SummaryWriter(log_dir='/home/liu.6221/PnP_fastMRI-master _Liu/summary')

    if resume:
        device = torch.device('cuda')
        checkpoint = torch.load('/home/liu.6221/PnP_fastMRI-master _Liu/model.pt')
        model = DnCNN(depth=5, image_channels=2, n_channels=64, snorm = True, realsnorm = False, L = 1, bnorm_type = 'mean', residual=False).cuda()
        model.load_state_dict(checkpoint['model'])
        optimizer = torch.optim.Adam(model.parameters(),lr = 0.001, weight_decay = 0)
        optimizer.load_state_dict(checkpoint['optimizer'])
        start_epoch = checkpoint['epoch']
        del checkpoint
    else:
        model = DnCNN(depth=5, image_channels=2, n_channels=64, snorm = True, realsnorm = False, L = 1, bnorm_type = 'mean', residual=False).cuda()
#         if 1:
#             model = torch.nn.DataParallel(model)
        optimizer = torch.optim.Adam(model.parameters(),lr = 0.001, weight_decay = 0)
        start_epoch = 0

    logging.info(model)

    train_loader = create_data_loaders()
    
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer,  step_size = 600, gamma = 0.1)

    for epoch in range(start_epoch, 800):
        scheduler.step(epoch)
        model.train()
        avg_loss = 0.
        losses = []
        start_epoch = start_iter = time.perf_counter()
        global_step = epoch * len(train_loader)
        for train_iter, data in enumerate(train_loader):
            inp, outp = data
            inp = inp.cuda()
            outp = outp.cuda()
            my_recon = model(inp)
            loss = F.mse_loss(my_recon, outp, reduction='sum')
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            losses.append(loss.item())
            avg_loss = 0.99 * avg_loss + 0.01 * loss.item() if train_iter > 0 else loss.item()
            writer.add_scalar('TrainLoss', loss.item(), global_step + train_iter)
            start_iter = time.perf_counter()
            train_time = time.perf_counter() - start_epoch
#             print('%4d %4d / %4d loss = %2.4f' % (epoch+1, train_iter, inp.size()[0], loss.item()/inp.size()[0]))
        torch.save(
            {
                'epoch': epoch,
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'exp_dir':  '/home/liu.6221/PnP_fastMRI-master _Liu/5layer_patch_0.1'
            },
            f='/home/liu.6221/PnP_fastMRI-master _Liu/5layer_patch_0.1/model.pt'
        )
        torch.save(model, '/home/liu.6221/PnP_fastMRI-master _Liu/5layer_patch_0.1/%03d_0.1.pt' % (epoch+1))   
#         save_model(args, args.exp_dir, epoch, model, optimizer, best_dev_loss, is_new_best)
        logging.info(
            f'Epoch = [{epoch:4d}/{3000:4d}] TrainLoss = {avg_loss:.4g} '
            f'TrainTime = {train_time:.4f}s',
        )
    writer.close()

# %%
if __name__ == '__main__':
#     args = create_arg_parser().parse_args()
    # restrict visible cuda devices
    os.environ['CUDA_VISIBLE_DEVICES'] = '3'
#     random.seed(1000)
#     np.random.seed(1000)
#     torch.manual_seed(1000)
    
    resume = 0
    
    main()
# Out:
# INFO:root:DnCNN(
#   (dncnn): Sequential(
#     (0): Conv2d(2, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ScalarMultiplyLayer(L=1)
#     (2): ReLU(inplace)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): ScalarMultiplyLayer(L=1)
#     (5): MeanOnlyBatchNorm(64, momentum=0.95 )
#     (6): ReLU(inplace)
#     (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (8): ScalarMultiplyLayer(L=1)
#     (9): MeanOnlyBatchNorm(64, momentum=0.95 )
#     (10): ReLU(inplace)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (12): ScalarMultiplyLayer(L=1)
#     (13): MeanOnlyBatchNorm(64, momentum=0.95 )
#     (14): ReLU(inplace)
#     (15): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (16): ScalarMultiplyLayer(L=1)
#   )
# )
# INFO:root:Epoch = [   0/3000] TrainLoss = 96.69 TrainTime = 29.2326s
# INFO:root:Epoch = [   1/3000] TrainLoss = 53.96 TrainTime = 27.5405s
# INFO:root:Epoch = [   2/3000] TrainLoss = 46.81 TrainTime = 26.1641s
# INFO:root:Epoch = [   3/3000] TrainLoss = 41.78 TrainTime = 27.2661s
# INFO:root:Epoch = [   4/3000] TrainLoss = 35.18 TrainTime = 27.2328s
# INFO:root:Epoch = [   5/3000] TrainLoss = 35.89 TrainTime = 26.6904s
# INFO:root:Epoch = [   6/3000] TrainLoss = 35.69 TrainTime = 27.1064s
# INFO:root:Epoch = [   7/3000] TrainLoss = 38.06 TrainTime = 27.0731s
# INFO:root:Epoch = [   8/3000] TrainLoss = 36.3 TrainTime = 27.4952s
# INFO:root:Epoch = [   9/3000] TrainLoss = 31.09 TrainTime = 26.6506s
# INFO:root:Epoch = [  10/3000] TrainLoss = 31.32 TrainTime = 27.3214s
# INFO:root:Epoch = [  11/3000] TrainLoss = 32.22 TrainTime = 26.5147s
# INFO:root:Epoch = [  12/3000] TrainLoss = 31.88 TrainTime = 28.1204s
# INFO:root:Epoch = [  13/3000] TrainLoss = 30.48 TrainTime = 26.2068s
# INFO:root:Epoch = [  14/3000] TrainLoss = 28.84 TrainTime = 27.0091s
# INFO:root:Epoch = [  15/3000] TrainLoss = 28.69 TrainTime = 27.5695s
# INFO:root:Epoch = [  16/3000] TrainLoss = 29.05 TrainTime = 27.8845s
# INFO:root:Epoch = [  17/3000] TrainLoss = 28.47 TrainTime = 25.4870s
# INFO:root:Epoch = [  18/3000] TrainLoss = 28.82 TrainTime = 26.5102s
# INFO:root:Epoch = [  19/3000] TrainLoss = 29.29 TrainTime = 27.8205s
# INFO:root:Epoch = [  20/3000] TrainLoss = 28.33 TrainTime = 25.9832s
# INFO:root:Epoch = [  21/3000] TrainLoss = 29.07 TrainTime = 27.1954s
# INFO:root:Epoch = [  22/3000] TrainLoss = 27.36 TrainTime = 26.4008s
# INFO:root:Epoch = [  23/3000] TrainLoss = 29.84 TrainTime = 27.9274s
# INFO:root:Epoch = [  24/3000] TrainLoss = 28.23 TrainTime = 26.7039s
# INFO:root:Epoch = [  25/3000] TrainLoss = 28.09 TrainTime = 27.4295s
# INFO:root:Epoch = [  26/3000] TrainLoss = 28.71 TrainTime = 27.7514s
# INFO:root:Epoch = [  27/3000] TrainLoss = 26.48 TrainTime = 25.9706s
# INFO:root:Epoch = [  28/3000] TrainLoss = 26.96 TrainTime = 28.1817s
# INFO:root:Epoch = [  29/3000] TrainLoss = 28.85 TrainTime = 25.7827s
# INFO:root:Epoch = [  30/3000] TrainLoss = 28.13 TrainTime = 26.3732s
# INFO:root:Epoch = [  31/3000] TrainLoss = 26.36 TrainTime = 27.0880s
# INFO:root:Epoch = [  32/3000] TrainLoss = 27.48 TrainTime = 27.0346s
# INFO:root:Epoch = [  33/3000] TrainLoss = 27.69 TrainTime = 25.3811s
# INFO:root:Epoch = [  34/3000] TrainLoss = 26.44 TrainTime = 26.8097s
# INFO:root:Epoch = [  35/3000] TrainLoss = 27.37 TrainTime = 28.1437s
# INFO:root:Epoch = [  36/3000] TrainLoss = 27.08 TrainTime = 27.2312s
# INFO:root:Epoch = [  37/3000] TrainLoss = 26.38 TrainTime = 28.0582s
# INFO:root:Epoch = [  38/3000] TrainLoss = 26.89 TrainTime = 27.3332s
# INFO:root:Epoch = [  39/3000] TrainLoss = 25.55 TrainTime = 26.5611s
# INFO:root:Epoch = [  40/3000] TrainLoss = 25.5 TrainTime = 28.4226s
# INFO:root:Epoch = [  41/3000] TrainLoss = 26.07 TrainTime = 27.7505s
# INFO:root:Epoch = [  42/3000] TrainLoss = 25.82 TrainTime = 27.0448s
# INFO:root:Epoch = [  43/3000] TrainLoss = 26.78 TrainTime = 27.1929s
# INFO:root:Epoch = [  44/3000] TrainLoss = 26.71 TrainTime = 27.9234s
# INFO:root:Epoch = [  45/3000] TrainLoss = 25.82 TrainTime = 27.8659s
# INFO:root:Epoch = [  46/3000] TrainLoss = 26.65 TrainTime = 27.3518s
# INFO:root:Epoch = [  47/3000] TrainLoss = 25.56 TrainTime = 28.0075s
# INFO:root:Epoch = [  48/3000] TrainLoss = 24.85 TrainTime = 26.8437s
# INFO:root:Epoch = [  49/3000] TrainLoss = 25.16 TrainTime = 27.3188s
# INFO:root:Epoch = [  50/3000] TrainLoss = 24.91 TrainTime = 27.3484s
# INFO:root:Epoch = [  51/3000] TrainLoss = 25.19 TrainTime = 26.7628s
# INFO:root:Epoch = [  52/3000] TrainLoss = 27.08 TrainTime = 27.8028s
# INFO:root:Epoch = [  53/3000] TrainLoss = 25.03 TrainTime = 27.1603s
# INFO:root:Epoch = [  54/3000] TrainLoss = 26 TrainTime = 28.3913s
# INFO:root:Epoch = [  55/3000] TrainLoss = 24.99 TrainTime = 28.4862s
# INFO:root:Epoch = [  56/3000] TrainLoss = 25.11 TrainTime = 27.7871s
# INFO:root:Epoch = [  57/3000] TrainLoss = 26.66 TrainTime = 27.7962s
# INFO:root:Epoch = [  58/3000] TrainLoss = 25.91 TrainTime = 26.6645s
# INFO:root:Epoch = [  59/3000] TrainLoss = 24.79 TrainTime = 27.3276s
# INFO:root:Epoch = [  60/3000] TrainLoss = 25.25 TrainTime = 26.9718s
# INFO:root:Epoch = [  61/3000] TrainLoss = 25.74 TrainTime = 27.1711s
# INFO:root:Epoch = [  62/3000] TrainLoss = 25.76 TrainTime = 26.9883s
# INFO:root:Epoch = [  63/3000] TrainLoss = 25.62 TrainTime = 26.5696s
# INFO:root:Epoch = [  64/3000] TrainLoss = 25.09 TrainTime = 26.6978s
# INFO:root:Epoch = [  65/3000] TrainLoss = 24.43 TrainTime = 29.6940s
# INFO:root:Epoch = [  66/3000] TrainLoss = 25.04 TrainTime = 27.7457s
# INFO:root:Epoch = [  67/3000] TrainLoss = 25.23 TrainTime = 26.8291s
# INFO:root:Epoch = [  68/3000] TrainLoss = 25.59 TrainTime = 27.7897s
# INFO:root:Epoch = [  69/3000] TrainLoss = 24.86 TrainTime = 32.2748s
# INFO:root:Epoch = [  70/3000] TrainLoss = 25.9 TrainTime = 28.2164s
# INFO:root:Epoch = [  71/3000] TrainLoss = 25.52 TrainTime = 27.7800s
# INFO:root:Epoch = [  72/3000] TrainLoss = 24.44 TrainTime = 29.1376s
# INFO:root:Epoch = [  73/3000] TrainLoss = 24.73 TrainTime = 27.3874s
# INFO:root:Epoch = [  74/3000] TrainLoss = 25.66 TrainTime = 27.1205s
# INFO:root:Epoch = [  75/3000] TrainLoss = 24.8 TrainTime = 28.7146s
# INFO:root:Epoch = [  76/3000] TrainLoss = 24.98 TrainTime = 26.8505s
# INFO:root:Epoch = [  77/3000] TrainLoss = 24.59 TrainTime = 27.4536s
# INFO:root:Epoch = [  78/3000] TrainLoss = 24.43 TrainTime = 29.0656s
# INFO:root:Epoch = [  79/3000] TrainLoss = 24.23 TrainTime = 27.1494s
# INFO:root:Epoch = [  80/3000] TrainLoss = 24.36 TrainTime = 28.4118s
# INFO:root:Epoch = [  81/3000] TrainLoss = 23.97 TrainTime = 28.1564s
# INFO:root:Epoch = [  82/3000] TrainLoss = 24.83 TrainTime = 26.9733s
# INFO:root:Epoch = [  83/3000] TrainLoss = 25.17 TrainTime = 28.2669s
# INFO:root:Epoch = [  84/3000] TrainLoss = 24.27 TrainTime = 29.5416s
# INFO:root:Epoch = [  85/3000] TrainLoss = 24.9 TrainTime = 28.4626s
# INFO:root:Epoch = [  86/3000] TrainLoss = 24.57 TrainTime = 27.3334s
# INFO:root:Epoch = [  87/3000] TrainLoss = 24.07 TrainTime = 27.9171s
# INFO:root:Epoch = [  88/3000] TrainLoss = 25.66 TrainTime = 27.7573s
# INFO:root:Epoch = [  89/3000] TrainLoss = 25.71 TrainTime = 27.5132s
# INFO:root:Epoch = [  90/3000] TrainLoss = 25.18 TrainTime = 29.1158s
# INFO:root:Epoch = [  91/3000] TrainLoss = 24.33 TrainTime = 26.9526s
# INFO:root:Epoch = [  92/3000] TrainLoss = 24.35 TrainTime = 28.1056s
# INFO:root:Epoch = [  93/3000] TrainLoss = 24.15 TrainTime = 27.6608s
# INFO:root:Epoch = [  94/3000] TrainLoss = 25.92 TrainTime = 27.9603s
# INFO:root:Epoch = [  95/3000] TrainLoss = 25.03 TrainTime = 27.6483s
# INFO:root:Epoch = [  96/3000] TrainLoss = 24.7 TrainTime = 27.5165s
# INFO:root:Epoch = [  97/3000] TrainLoss = 24.8 TrainTime = 28.4875s
# INFO:root:Epoch = [  98/3000] TrainLoss = 25 TrainTime = 28.0810s
# INFO:root:Epoch = [  99/3000] TrainLoss = 24.26 TrainTime = 27.0326s
# INFO:root:Epoch = [ 100/3000] TrainLoss = 24.81 TrainTime = 27.1360s
# INFO:root:Epoch = [ 101/3000] TrainLoss = 24.09 TrainTime = 29.2087s
# INFO:root:Epoch = [ 102/3000] TrainLoss = 25.25 TrainTime = 27.4814s
# INFO:root:Epoch = [ 103/3000] TrainLoss = 24.03 TrainTime = 28.0806s
# INFO:root:Epoch = [ 104/3000] TrainLoss = 25.28 TrainTime = 28.0310s
# INFO:root:Epoch = [ 105/3000] TrainLoss = 24.65 TrainTime = 27.5672s
# INFO:root:Epoch = [ 106/3000] TrainLoss = 24.05 TrainTime = 28.2105s
# INFO:root:Epoch = [ 107/3000] TrainLoss = 25.73 TrainTime = 27.9348s
# INFO:root:Epoch = [ 108/3000] TrainLoss = 24.15 TrainTime = 29.5742s
# INFO:root:Epoch = [ 109/3000] TrainLoss = 24.76 TrainTime = 28.6836s
# INFO:root:Epoch = [ 110/3000] TrainLoss = 24.2 TrainTime = 28.1178s
# INFO:root:Epoch = [ 111/3000] TrainLoss = 25.7 TrainTime = 31.6328s
# INFO:root:Epoch = [ 112/3000] TrainLoss = 23.86 TrainTime = 26.9748s
# INFO:root:Epoch = [ 113/3000] TrainLoss = 24.14 TrainTime = 28.5979s
# INFO:root:Epoch = [ 114/3000] TrainLoss = 23.83 TrainTime = 29.5034s
# INFO:root:Epoch = [ 115/3000] TrainLoss = 23.61 TrainTime = 28.8828s
# INFO:root:Epoch = [ 116/3000] TrainLoss = 23.78 TrainTime = 28.3405s
# INFO:root:Epoch = [ 117/3000] TrainLoss = 23.77 TrainTime = 29.1197s
# INFO:root:Epoch = [ 118/3000] TrainLoss = 24.27 TrainTime = 29.2509s
# INFO:root:Epoch = [ 119/3000] TrainLoss = 23.79 TrainTime = 27.8307s
# INFO:root:Epoch = [ 120/3000] TrainLoss = 24.58 TrainTime = 29.6581s
# INFO:root:Epoch = [ 121/3000] TrainLoss = 23.49 TrainTime = 28.8981s
# INFO:root:Epoch = [ 122/3000] TrainLoss = 24.11 TrainTime = 28.9303s
# INFO:root:Epoch = [ 123/3000] TrainLoss = 23.99 TrainTime = 28.6486s
# INFO:root:Epoch = [ 124/3000] TrainLoss = 24.28 TrainTime = 28.6415s
# INFO:root:Epoch = [ 125/3000] TrainLoss = 23.42 TrainTime = 28.6190s
# INFO:root:Epoch = [ 126/3000] TrainLoss = 24.03 TrainTime = 28.7424s
# INFO:root:Epoch = [ 127/3000] TrainLoss = 24.48 TrainTime = 31.1242s
# INFO:root:Epoch = [ 128/3000] TrainLoss = 24.6 TrainTime = 29.8642s
# INFO:root:Epoch = [ 129/3000] TrainLoss = 24.02 TrainTime = 29.3939s
# INFO:root:Epoch = [ 130/3000] TrainLoss = 23.66 TrainTime = 28.3900s
# INFO:root:Epoch = [ 131/3000] TrainLoss = 24 TrainTime = 27.9981s
# INFO:root:Epoch = [ 132/3000] TrainLoss = 23.8 TrainTime = 31.3012s
# INFO:root:Epoch = [ 133/3000] TrainLoss = 23.78 TrainTime = 29.0147s
# INFO:root:Epoch = [ 134/3000] TrainLoss = 23.74 TrainTime = 28.6235s
# INFO:root:Epoch = [ 135/3000] TrainLoss = 23.39 TrainTime = 28.8098s
# INFO:root:Epoch = [ 136/3000] TrainLoss = 23.75 TrainTime = 29.3607s
# INFO:root:Epoch = [ 137/3000] TrainLoss = 23.64 TrainTime = 30.3847s
# INFO:root:Epoch = [ 138/3000] TrainLoss = 24.35 TrainTime = 28.4257s
# INFO:root:Epoch = [ 139/3000] TrainLoss = 24.65 TrainTime = 29.6807s
# INFO:root:Epoch = [ 140/3000] TrainLoss = 23.71 TrainTime = 29.5430s
# INFO:root:Epoch = [ 141/3000] TrainLoss = 23.84 TrainTime = 31.4261s
# INFO:root:Epoch = [ 142/3000] TrainLoss = 23.85 TrainTime = 29.3154s
# INFO:root:Epoch = [ 143/3000] TrainLoss = 24.73 TrainTime = 28.8897s
# INFO:root:Epoch = [ 144/3000] TrainLoss = 23.86 TrainTime = 28.3921s
# INFO:root:Epoch = [ 145/3000] TrainLoss = 24.16 TrainTime = 28.4753s
# INFO:root:Epoch = [ 146/3000] TrainLoss = 23.66 TrainTime = 27.9741s
# INFO:root:Epoch = [ 147/3000] TrainLoss = 23.6 TrainTime = 28.4997s
# INFO:root:Epoch = [ 148/3000] TrainLoss = 23.65 TrainTime = 28.7362s
# INFO:root:Epoch = [ 149/3000] TrainLoss = 23.28 TrainTime = 29.6789s
# INFO:root:Epoch = [ 150/3000] TrainLoss = 24.08 TrainTime = 31.3190s
# INFO:root:Epoch = [ 151/3000] TrainLoss = 24.3 TrainTime = 28.8286s
# INFO:root:Epoch = [ 152/3000] TrainLoss = 23.31 TrainTime = 29.6905s
# INFO:root:Epoch = [ 153/3000] TrainLoss = 23.94 TrainTime = 28.7996s
# INFO:root:Epoch = [ 154/3000] TrainLoss = 24.17 TrainTime = 28.1119s
# INFO:root:Epoch = [ 155/3000] TrainLoss = 23.02 TrainTime = 28.7582s
# INFO:root:Epoch = [ 156/3000] TrainLoss = 23.89 TrainTime = 30.8152s
# INFO:root:Epoch = [ 157/3000] TrainLoss = 23.89 TrainTime = 29.0415s
# INFO:root:Epoch = [ 158/3000] TrainLoss = 23.68 TrainTime = 28.8934s
# INFO:root:Epoch = [ 159/3000] TrainLoss = 23.78 TrainTime = 29.9029s
# INFO:root:Epoch = [ 160/3000] TrainLoss = 23.83 TrainTime = 29.3988s
# INFO:root:Epoch = [ 161/3000] TrainLoss = 23.74 TrainTime = 28.9104s
# INFO:root:Epoch = [ 162/3000] TrainLoss = 23.64 TrainTime = 31.5156s
# INFO:root:Epoch = [ 163/3000] TrainLoss = 23.51 TrainTime = 31.0550s
# INFO:root:Epoch = [ 164/3000] TrainLoss = 23.56 TrainTime = 30.1558s
# INFO:root:Epoch = [ 165/3000] TrainLoss = 23.37 TrainTime = 29.6488s
# INFO:root:Epoch = [ 166/3000] TrainLoss = 23.66 TrainTime = 28.9677s
# INFO:root:Epoch = [ 167/3000] TrainLoss = 23.42 TrainTime = 29.6927s
# INFO:root:Epoch = [ 168/3000] TrainLoss = 24.12 TrainTime = 31.1554s
# INFO:root:Epoch = [ 169/3000] TrainLoss = 23.53 TrainTime = 29.4096s
# INFO:root:Epoch = [ 170/3000] TrainLoss = 23.65 TrainTime = 30.1248s
# INFO:root:Epoch = [ 171/3000] TrainLoss = 23.23 TrainTime = 28.1416s
# INFO:root:Epoch = [ 172/3000] TrainLoss = 24.41 TrainTime = 30.6703s
# INFO:root:Epoch = [ 173/3000] TrainLoss = 23.56 TrainTime = 29.4470s
# INFO:root:Epoch = [ 174/3000] TrainLoss = 23.64 TrainTime = 29.5818s
# INFO:root:Epoch = [ 175/3000] TrainLoss = 23.08 TrainTime = 29.2561s
# INFO:root:Epoch = [ 176/3000] TrainLoss = 24 TrainTime = 29.1720s
# INFO:root:Epoch = [ 177/3000] TrainLoss = 23.81 TrainTime = 30.6148s
# INFO:root:Epoch = [ 178/3000] TrainLoss = 23.2 TrainTime = 32.2132s
# INFO:root:Epoch = [ 179/3000] TrainLoss = 23.52 TrainTime = 29.5680s
# INFO:root:Epoch = [ 180/3000] TrainLoss = 23.35 TrainTime = 30.3838s
# INFO:root:Epoch = [ 181/3000] TrainLoss = 23.38 TrainTime = 29.9277s
# INFO:root:Epoch = [ 182/3000] TrainLoss = 23.53 TrainTime = 29.9796s
# INFO:root:Epoch = [ 183/3000] TrainLoss = 23.53 TrainTime = 30.2233s
# INFO:root:Epoch = [ 184/3000] TrainLoss = 23.62 TrainTime = 30.1264s
# INFO:root:Epoch = [ 185/3000] TrainLoss = 23.44 TrainTime = 28.9856s
# INFO:root:Epoch = [ 186/3000] TrainLoss = 23.32 TrainTime = 29.1363s
# INFO:root:Epoch = [ 187/3000] TrainLoss = 23.38 TrainTime = 29.4826s
# INFO:root:Epoch = [ 188/3000] TrainLoss = 23.26 TrainTime = 30.8291s
# INFO:root:Epoch = [ 189/3000] TrainLoss = 23.46 TrainTime = 28.9870s
# INFO:root:Epoch = [ 190/3000] TrainLoss = 24.69 TrainTime = 29.8449s
# INFO:root:Epoch = [ 191/3000] TrainLoss = 24.58 TrainTime = 30.1169s
# INFO:root:Epoch = [ 192/3000] TrainLoss = 23.61 TrainTime = 30.1431s
# INFO:root:Epoch = [ 193/3000] TrainLoss = 23.9 TrainTime = 30.6227s
# INFO:root:Epoch = [ 194/3000] TrainLoss = 23.05 TrainTime = 30.2906s
# INFO:root:Epoch = [ 195/3000] TrainLoss = 23.38 TrainTime = 29.4473s
# INFO:root:Epoch = [ 196/3000] TrainLoss = 23.06 TrainTime = 29.7762s
# INFO:root:Epoch = [ 197/3000] TrainLoss = 23.29 TrainTime = 30.8830s
# INFO:root:Epoch = [ 198/3000] TrainLoss = 23.8 TrainTime = 29.9235s
# INFO:root:Epoch = [ 199/3000] TrainLoss = 23.4 TrainTime = 30.4417s
# INFO:root:Epoch = [ 200/3000] TrainLoss = 23.5 TrainTime = 32.0132s
# INFO:root:Epoch = [ 201/3000] TrainLoss = 23.43 TrainTime = 29.4913s
# INFO:root:Epoch = [ 202/3000] TrainLoss = 23.65 TrainTime = 28.9577s
# INFO:root:Epoch = [ 203/3000] TrainLoss = 23.8 TrainTime = 32.0701s
# INFO:root:Epoch = [ 204/3000] TrainLoss = 23.02 TrainTime = 30.4265s
# INFO:root:Epoch = [ 205/3000] TrainLoss = 23.57 TrainTime = 30.0588s
# INFO:root:Epoch = [ 206/3000] TrainLoss = 23.07 TrainTime = 30.4313s
# INFO:root:Epoch = [ 207/3000] TrainLoss = 23.41 TrainTime = 28.9440s
# INFO:root:Epoch = [ 208/3000] TrainLoss = 23.53 TrainTime = 29.6794s
# INFO:root:Epoch = [ 209/3000] TrainLoss = 24.47 TrainTime = 30.3283s
# INFO:root:Epoch = [ 210/3000] TrainLoss = 23.34 TrainTime = 29.8467s
# INFO:root:Epoch = [ 211/3000] TrainLoss = 23.14 TrainTime = 31.3135s
# INFO:root:Epoch = [ 212/3000] TrainLoss = 23.79 TrainTime = 29.4361s
# INFO:root:Epoch = [ 213/3000] TrainLoss = 23.72 TrainTime = 30.3151s
# INFO:root:Epoch = [ 214/3000] TrainLoss = 24.12 TrainTime = 30.0247s
# INFO:root:Epoch = [ 215/3000] TrainLoss = 23.02 TrainTime = 31.1332s
# INFO:root:Epoch = [ 216/3000] TrainLoss = 22.97 TrainTime = 30.6479s
# INFO:root:Epoch = [ 217/3000] TrainLoss = 23.33 TrainTime = 32.0717s
# INFO:root:Epoch = [ 218/3000] TrainLoss = 22.97 TrainTime = 29.7271s
# INFO:root:Epoch = [ 219/3000] TrainLoss = 23.68 TrainTime = 29.7466s
# INFO:root:Epoch = [ 220/3000] TrainLoss = 23.15 TrainTime = 30.6346s
# INFO:root:Epoch = [ 221/3000] TrainLoss = 23.33 TrainTime = 30.6030s
# INFO:root:Epoch = [ 222/3000] TrainLoss = 23.2 TrainTime = 33.6128s
# INFO:root:Epoch = [ 223/3000] TrainLoss = 22.67 TrainTime = 30.5352s
# INFO:root:Epoch = [ 224/3000] TrainLoss = 23.45 TrainTime = 30.4453s
# INFO:root:Epoch = [ 225/3000] TrainLoss = 23.68 TrainTime = 39.3444s
# INFO:root:Epoch = [ 226/3000] TrainLoss = 23.01 TrainTime = 29.6987s
# INFO:root:Epoch = [ 227/3000] TrainLoss = 22.91 TrainTime = 30.7281s
# INFO:root:Epoch = [ 228/3000] TrainLoss = 22.99 TrainTime = 32.1122s
# INFO:root:Epoch = [ 229/3000] TrainLoss = 23.09 TrainTime = 31.1746s
# INFO:root:Epoch = [ 230/3000] TrainLoss = 22.69 TrainTime = 30.7062s
# INFO:root:Epoch = [ 231/3000] TrainLoss = 23.41 TrainTime = 32.4739s
# INFO:root:Epoch = [ 232/3000] TrainLoss = 23.37 TrainTime = 31.5412s
# INFO:root:Epoch = [ 233/3000] TrainLoss = 23.3 TrainTime = 30.6380s
# INFO:root:Epoch = [ 234/3000] TrainLoss = 23.91 TrainTime = 33.8441s
# INFO:root:Epoch = [ 235/3000] TrainLoss = 23.64 TrainTime = 30.6789s
# INFO:root:Epoch = [ 236/3000] TrainLoss = 23.15 TrainTime = 29.4085s
# INFO:root:Epoch = [ 237/3000] TrainLoss = 23.07 TrainTime = 30.6639s
# INFO:root:Epoch = [ 238/3000] TrainLoss = 23.28 TrainTime = 34.5902s
# INFO:root:Epoch = [ 239/3000] TrainLoss = 23.34 TrainTime = 31.3709s
# INFO:root:Epoch = [ 240/3000] TrainLoss = 23.36 TrainTime = 30.7023s
# INFO:root:Epoch = [ 241/3000] TrainLoss = 23.2 TrainTime = 31.8787s
# INFO:root:Epoch = [ 242/3000] TrainLoss = 23.12 TrainTime = 31.5862s
# INFO:root:Epoch = [ 243/3000] TrainLoss = 23.33 TrainTime = 31.4393s
# INFO:root:Epoch = [ 244/3000] TrainLoss = 23.45 TrainTime = 31.3824s
# INFO:root:Epoch = [ 245/3000] TrainLoss = 23.56 TrainTime = 31.6982s
# INFO:root:Epoch = [ 246/3000] TrainLoss = 23.14 TrainTime = 30.8565s
# INFO:root:Epoch = [ 247/3000] TrainLoss = 22.83 TrainTime = 31.0958s
# INFO:root:Epoch = [ 248/3000] TrainLoss = 23.43 TrainTime = 32.7106s
# INFO:root:Epoch = [ 249/3000] TrainLoss = 22.97 TrainTime = 30.6671s
# INFO:root:Epoch = [ 250/3000] TrainLoss = 23.12 TrainTime = 33.3601s
# INFO:root:Epoch = [ 251/3000] TrainLoss = 22.93 TrainTime = 30.3264s
# INFO:root:Epoch = [ 252/3000] TrainLoss = 23.3 TrainTime = 32.6520s
# INFO:root:Epoch = [ 253/3000] TrainLoss = 22.53 TrainTime = 34.8414s
# INFO:root:Epoch = [ 254/3000] TrainLoss = 23.25 TrainTime = 30.7902s
# INFO:root:Epoch = [ 255/3000] TrainLoss = 23.13 TrainTime = 32.4858s
# INFO:root:Epoch = [ 256/3000] TrainLoss = 23.21 TrainTime = 31.6833s
# INFO:root:Epoch = [ 257/3000] TrainLoss = 25.8 TrainTime = 31.4186s
# INFO:root:Epoch = [ 258/3000] TrainLoss = 22.78 TrainTime = 29.7462s
# INFO:root:Epoch = [ 259/3000] TrainLoss = 23.02 TrainTime = 30.7121s
# INFO:root:Epoch = [ 260/3000] TrainLoss = 23.05 TrainTime = 31.3018s
# INFO:root:Epoch = [ 261/3000] TrainLoss = 23.37 TrainTime = 31.6989s
# INFO:root:Epoch = [ 262/3000] TrainLoss = 23.54 TrainTime = 33.5115s
# INFO:root:Epoch = [ 263/3000] TrainLoss = 23.08 TrainTime = 30.7164s
# INFO:root:Epoch = [ 264/3000] TrainLoss = 23.32 TrainTime = 32.6167s
# INFO:root:Epoch = [ 265/3000] TrainLoss = 23.18 TrainTime = 31.4351s
# INFO:root:Epoch = [ 266/3000] TrainLoss = 23.33 TrainTime = 32.1133s
# INFO:root:Epoch = [ 267/3000] TrainLoss = 23.6 TrainTime = 31.2832s
# INFO:root:Epoch = [ 268/3000] TrainLoss = 22.89 TrainTime = 32.2529s
# INFO:root:Epoch = [ 269/3000] TrainLoss = 22.73 TrainTime = 30.4628s
# INFO:root:Epoch = [ 270/3000] TrainLoss = 23.19 TrainTime = 32.2898s
# INFO:root:Epoch = [ 271/3000] TrainLoss = 23.04 TrainTime = 33.5003s
# INFO:root:Epoch = [ 272/3000] TrainLoss = 22.82 TrainTime = 32.1570s
# INFO:root:Epoch = [ 273/3000] TrainLoss = 23.23 TrainTime = 30.8629s
# INFO:root:Epoch = [ 274/3000] TrainLoss = 22.95 TrainTime = 32.2005s
# INFO:root:Epoch = [ 275/3000] TrainLoss = 22.76 TrainTime = 31.2680s
# INFO:root:Epoch = [ 276/3000] TrainLoss = 23.17 TrainTime = 33.7495s
# INFO:root:Epoch = [ 277/3000] TrainLoss = 23.08 TrainTime = 32.2926s
# INFO:root:Epoch = [ 278/3000] TrainLoss = 23.33 TrainTime = 33.3765s
# INFO:root:Epoch = [ 279/3000] TrainLoss = 23.32 TrainTime = 31.8583s
# INFO:root:Epoch = [ 280/3000] TrainLoss = 22.92 TrainTime = 30.3287s
# INFO:root:Epoch = [ 281/3000] TrainLoss = 23.64 TrainTime = 31.0747s
# INFO:root:Epoch = [ 282/3000] TrainLoss = 23.01 TrainTime = 30.4795s
# INFO:root:Epoch = [ 283/3000] TrainLoss = 23.48 TrainTime = 31.4654s
# INFO:root:Epoch = [ 284/3000] TrainLoss = 23.41 TrainTime = 32.4420s
# INFO:root:Epoch = [ 285/3000] TrainLoss = 22.91 TrainTime = 34.4858s
# INFO:root:Epoch = [ 286/3000] TrainLoss = 23.27 TrainTime = 30.9702s
# INFO:root:Epoch = [ 287/3000] TrainLoss = 24.37 TrainTime = 32.5469s
# INFO:root:Epoch = [ 288/3000] TrainLoss = 23.03 TrainTime = 32.8670s
# INFO:root:Epoch = [ 289/3000] TrainLoss = 22.9 TrainTime = 31.1906s
# INFO:root:Epoch = [ 290/3000] TrainLoss = 23.69 TrainTime = 33.5573s
# INFO:root:Epoch = [ 291/3000] TrainLoss = 23.09 TrainTime = 32.3161s
# INFO:root:Epoch = [ 292/3000] TrainLoss = 22.96 TrainTime = 30.7659s
# INFO:root:Epoch = [ 293/3000] TrainLoss = 22.97 TrainTime = 31.1595s
# INFO:root:Epoch = [ 294/3000] TrainLoss = 22.95 TrainTime = 32.3105s
# INFO:root:Epoch = [ 295/3000] TrainLoss = 22.71 TrainTime = 30.7814s
# INFO:root:Epoch = [ 296/3000] TrainLoss = 22.73 TrainTime = 32.0106s
# INFO:root:Epoch = [ 297/3000] TrainLoss = 23.21 TrainTime = 31.8155s
# INFO:root:Epoch = [ 298/3000] TrainLoss = 22.7 TrainTime = 32.8559s
# INFO:root:Epoch = [ 299/3000] TrainLoss = 22.94 TrainTime = 31.1699s
# INFO:root:Epoch = [ 300/3000] TrainLoss = 23.22 TrainTime = 31.8889s
# INFO:root:Epoch = [ 301/3000] TrainLoss = 23 TrainTime = 31.4383s
# INFO:root:Epoch = [ 302/3000] TrainLoss = 22.66 TrainTime = 31.3457s
# INFO:root:Epoch = [ 303/3000] TrainLoss = 23.32 TrainTime = 32.7949s
# INFO:root:Epoch = [ 304/3000] TrainLoss = 23.03 TrainTime = 31.6192s
# INFO:root:Epoch = [ 305/3000] TrainLoss = 22.92 TrainTime = 31.3162s
# INFO:root:Epoch = [ 306/3000] TrainLoss = 23.08 TrainTime = 34.1411s
# INFO:root:Epoch = [ 307/3000] TrainLoss = 23.16 TrainTime = 31.2713s
# INFO:root:Epoch = [ 308/3000] TrainLoss = 23.8 TrainTime = 32.4939s
# INFO:root:Epoch = [ 309/3000] TrainLoss = 23.01 TrainTime = 34.2017s
# INFO:root:Epoch = [ 310/3000] TrainLoss = 22.74 TrainTime = 31.8561s
# INFO:root:Epoch = [ 311/3000] TrainLoss = 23.13 TrainTime = 32.2244s
# INFO:root:Epoch = [ 312/3000] TrainLoss = 22.72 TrainTime = 32.6003s
# INFO:root:Epoch = [ 313/3000] TrainLoss = 23.38 TrainTime = 31.5829s
# INFO:root:Epoch = [ 314/3000] TrainLoss = 23.03 TrainTime = 32.8729s
# INFO:root:Epoch = [ 315/3000] TrainLoss = 23.16 TrainTime = 33.0156s
# INFO:root:Epoch = [ 316/3000] TrainLoss = 23.03 TrainTime = 31.4501s
# INFO:root:Epoch = [ 317/3000] TrainLoss = 23.27 TrainTime = 33.9133s
# INFO:root:Epoch = [ 318/3000] TrainLoss = 23.24 TrainTime = 34.2037s
# INFO:root:Epoch = [ 319/3000] TrainLoss = 22.98 TrainTime = 32.1609s
# INFO:root:Epoch = [ 320/3000] TrainLoss = 23.03 TrainTime = 32.0016s
# INFO:root:Epoch = [ 321/3000] TrainLoss = 22.73 TrainTime = 33.2946s
# INFO:root:Epoch = [ 322/3000] TrainLoss = 23.23 TrainTime = 31.7293s
# INFO:root:Epoch = [ 323/3000] TrainLoss = 23.3 TrainTime = 33.7482s
# INFO:root:Epoch = [ 324/3000] TrainLoss = 23.66 TrainTime = 32.8055s
# INFO:root:Epoch = [ 325/3000] TrainLoss = 23.05 TrainTime = 33.6914s
# INFO:root:Epoch = [ 326/3000] TrainLoss = 23.56 TrainTime = 32.1987s
# INFO:root:Epoch = [ 327/3000] TrainLoss = 22.88 TrainTime = 32.6548s
# INFO:root:Epoch = [ 328/3000] TrainLoss = 22.76 TrainTime = 32.1479s
# INFO:root:Epoch = [ 329/3000] TrainLoss = 23.05 TrainTime = 31.5703s
# INFO:root:Epoch = [ 330/3000] TrainLoss = 22.81 TrainTime = 31.9273s
# INFO:root:Epoch = [ 331/3000] TrainLoss = 23.25 TrainTime = 32.9699s
# INFO:root:Epoch = [ 332/3000] TrainLoss = 23.12 TrainTime = 32.8361s
# INFO:root:Epoch = [ 333/3000] TrainLoss = 22.96 TrainTime = 31.6853s
# INFO:root:Epoch = [ 334/3000] TrainLoss = 22.99 TrainTime = 31.9291s
# INFO:root:Epoch = [ 335/3000] TrainLoss = 22.89 TrainTime = 33.0909s
# INFO:root:Epoch = [ 336/3000] TrainLoss = 22.48 TrainTime = 31.4796s
# INFO:root:Epoch = [ 337/3000] TrainLoss = 22.81 TrainTime = 33.1233s
# INFO:root:Epoch = [ 338/3000] TrainLoss = 22.71 TrainTime = 34.7938s
# INFO:root:Epoch = [ 339/3000] TrainLoss = 22.75 TrainTime = 33.1913s
# INFO:root:Epoch = [ 340/3000] TrainLoss = 22.8 TrainTime = 32.6946s
# INFO:root:Epoch = [ 341/3000] TrainLoss = 22.67 TrainTime = 32.1628s
# INFO:root:Epoch = [ 342/3000] TrainLoss = 23.29 TrainTime = 31.7696s
# INFO:root:Epoch = [ 343/3000] TrainLoss = 23.62 TrainTime = 33.0201s
# INFO:root:Epoch = [ 344/3000] TrainLoss = 22.99 TrainTime = 31.7660s
# INFO:root:Epoch = [ 345/3000] TrainLoss = 23.08 TrainTime = 32.3935s
# INFO:root:Epoch = [ 346/3000] TrainLoss = 22.89 TrainTime = 33.5769s
# INFO:root:Epoch = [ 347/3000] TrainLoss = 22.58 TrainTime = 32.6542s
# INFO:root:Epoch = [ 348/3000] TrainLoss = 22.81 TrainTime = 31.7185s
# INFO:root:Epoch = [ 349/3000] TrainLoss = 23 TrainTime = 32.8981s
# INFO:root:Epoch = [ 350/3000] TrainLoss = 22.84 TrainTime = 33.0670s
# INFO:root:Epoch = [ 351/3000] TrainLoss = 23.06 TrainTime = 32.5330s
# INFO:root:Epoch = [ 352/3000] TrainLoss = 22.58 TrainTime = 32.6333s
# INFO:root:Epoch = [ 353/3000] TrainLoss = 23.39 TrainTime = 34.0941s
# INFO:root:Epoch = [ 354/3000] TrainLoss = 22.64 TrainTime = 37.2638s
# INFO:root:Epoch = [ 355/3000] TrainLoss = 23.01 TrainTime = 34.0128s
# INFO:root:Epoch = [ 356/3000] TrainLoss = 23.19 TrainTime = 41.0486s
# INFO:root:Epoch = [ 357/3000] TrainLoss = 22.63 TrainTime = 33.3907s
# INFO:root:Epoch = [ 358/3000] TrainLoss = 22.61 TrainTime = 31.8207s
# INFO:root:Epoch = [ 359/3000] TrainLoss = 24.11 TrainTime = 35.9961s
# INFO:root:Epoch = [ 360/3000] TrainLoss = 22.56 TrainTime = 34.5257s
# INFO:root:Epoch = [ 361/3000] TrainLoss = 22.77 TrainTime = 36.3969s
# INFO:root:Epoch = [ 362/3000] TrainLoss = 22.52 TrainTime = 34.2422s
# INFO:root:Epoch = [ 363/3000] TrainLoss = 23.18 TrainTime = 36.1016s
# INFO:root:Epoch = [ 364/3000] TrainLoss = 23.31 TrainTime = 32.8258s
# INFO:root:Epoch = [ 365/3000] TrainLoss = 23.26 TrainTime = 32.7544s
# INFO:root:Epoch = [ 366/3000] TrainLoss = 22.84 TrainTime = 35.7356s
# INFO:root:Epoch = [ 367/3000] TrainLoss = 22.86 TrainTime = 32.7478s
# INFO:root:Epoch = [ 368/3000] TrainLoss = 22.67 TrainTime = 36.3247s
# INFO:root:Epoch = [ 369/3000] TrainLoss = 22.94 TrainTime = 33.0615s
# INFO:root:Epoch = [ 370/3000] TrainLoss = 22.83 TrainTime = 34.4800s
# INFO:root:Epoch = [ 371/3000] TrainLoss = 23.01 TrainTime = 36.3458s
# INFO:root:Epoch = [ 372/3000] TrainLoss = 22.7 TrainTime = 35.1716s
# INFO:root:Epoch = [ 373/3000] TrainLoss = 23.41 TrainTime = 37.2510s
# INFO:root:Epoch = [ 374/3000] TrainLoss = 23.2 TrainTime = 33.0784s
# INFO:root:Epoch = [ 375/3000] TrainLoss = 23.19 TrainTime = 35.8654s
# INFO:root:Epoch = [ 376/3000] TrainLoss = 22.82 TrainTime = 35.3082s
# INFO:root:Epoch = [ 377/3000] TrainLoss = 22.94 TrainTime = 34.2993s
# INFO:root:Epoch = [ 378/3000] TrainLoss = 22.75 TrainTime = 35.0300s
# INFO:root:Epoch = [ 379/3000] TrainLoss = 22.42 TrainTime = 36.6024s
# INFO:root:Epoch = [ 380/3000] TrainLoss = 23.07 TrainTime = 37.1589s
# INFO:root:Epoch = [ 381/3000] TrainLoss = 23.03 TrainTime = 33.5044s
# INFO:root:Epoch = [ 382/3000] TrainLoss = 22.92 TrainTime = 38.0963s
# INFO:root:Epoch = [ 383/3000] TrainLoss = 22.59 TrainTime = 35.9071s
# INFO:root:Epoch = [ 384/3000] TrainLoss = 22.71 TrainTime = 34.4050s
# INFO:root:Epoch = [ 385/3000] TrainLoss = 22.98 TrainTime = 35.8856s
# INFO:root:Epoch = [ 386/3000] TrainLoss = 22.69 TrainTime = 34.5032s
# INFO:root:Epoch = [ 387/3000] TrainLoss = 22.9 TrainTime = 36.1599s
# INFO:root:Epoch = [ 388/3000] TrainLoss = 22.97 TrainTime = 34.1999s
# INFO:root:Epoch = [ 389/3000] TrainLoss = 22.61 TrainTime = 37.1989s
# INFO:root:Epoch = [ 390/3000] TrainLoss = 22.87 TrainTime = 36.2823s
# INFO:root:Epoch = [ 391/3000] TrainLoss = 22.64 TrainTime = 38.2833s
# INFO:root:Epoch = [ 392/3000] TrainLoss = 22.84 TrainTime = 33.1534s
# INFO:root:Epoch = [ 393/3000] TrainLoss = 22.46 TrainTime = 32.7560s
# INFO:root:Epoch = [ 394/3000] TrainLoss = 22.71 TrainTime = 38.3154s
# INFO:root:Epoch = [ 395/3000] TrainLoss = 22.88 TrainTime = 34.1398s
# INFO:root:Epoch = [ 396/3000] TrainLoss = 22.71 TrainTime = 42.6064s
# INFO:root:Epoch = [ 397/3000] TrainLoss = 22.79 TrainTime = 43.0925s
# INFO:root:Epoch = [ 398/3000] TrainLoss = 23.14 TrainTime = 46.5748s
# INFO:root:Epoch = [ 399/3000] TrainLoss = 22.68 TrainTime = 39.7522s
# INFO:root:Epoch = [ 400/3000] TrainLoss = 22.52 TrainTime = 52.0445s
# INFO:root:Epoch = [ 401/3000] TrainLoss = 22.76 TrainTime = 42.8787s
# INFO:root:Epoch = [ 402/3000] TrainLoss = 22.73 TrainTime = 38.1179s
# INFO:root:Epoch = [ 403/3000] TrainLoss = 22.81 TrainTime = 33.9271s
# INFO:root:Epoch = [ 404/3000] TrainLoss = 22.83 TrainTime = 37.7779s
# INFO:root:Epoch = [ 405/3000] TrainLoss = 22.83 TrainTime = 36.9792s
# INFO:root:Epoch = [ 406/3000] TrainLoss = 22.94 TrainTime = 34.0838s
# INFO:root:Epoch = [ 407/3000] TrainLoss = 22.88 TrainTime = 36.6015s
# INFO:root:Epoch = [ 408/3000] TrainLoss = 22.74 TrainTime = 34.7694s
# INFO:root:Epoch = [ 409/3000] TrainLoss = 22.83 TrainTime = 37.5299s
# INFO:root:Epoch = [ 410/3000] TrainLoss = 22.88 TrainTime = 36.2904s
# INFO:root:Epoch = [ 411/3000] TrainLoss = 22.85 TrainTime = 33.5177s
# INFO:root:Epoch = [ 412/3000] TrainLoss = 22.99 TrainTime = 34.1352s
# INFO:root:Epoch = [ 413/3000] TrainLoss = 23.28 TrainTime = 33.5599s
# INFO:root:Epoch = [ 414/3000] TrainLoss = 22.96 TrainTime = 37.1234s
# INFO:root:Epoch = [ 415/3000] TrainLoss = 22.95 TrainTime = 36.4010s
# INFO:root:Epoch = [ 416/3000] TrainLoss = 22.65 TrainTime = 39.0068s
# INFO:root:Epoch = [ 417/3000] TrainLoss = 22.68 TrainTime = 34.4503s
# INFO:root:Epoch = [ 418/3000] TrainLoss = 22.64 TrainTime = 36.7581s
# INFO:root:Epoch = [ 419/3000] TrainLoss = 22.6 TrainTime = 36.5295s
# INFO:root:Epoch = [ 420/3000] TrainLoss = 22.5 TrainTime = 34.8705s
# INFO:root:Epoch = [ 421/3000] TrainLoss = 22.63 TrainTime = 37.0479s
# INFO:root:Epoch = [ 422/3000] TrainLoss = 22.65 TrainTime = 34.9277s
# INFO:root:Epoch = [ 423/3000] TrainLoss = 22.43 TrainTime = 37.6472s
# INFO:root:Epoch = [ 424/3000] TrainLoss = 22.35 TrainTime = 37.4751s
# INFO:root:Epoch = [ 425/3000] TrainLoss = 22.66 TrainTime = 38.8760s
# INFO:root:Epoch = [ 426/3000] TrainLoss = 22.85 TrainTime = 43.7677s
# INFO:root:Epoch = [ 427/3000] TrainLoss = 22.51 TrainTime = 42.8247s
# INFO:root:Epoch = [ 428/3000] TrainLoss = 22.72 TrainTime = 41.0059s
# INFO:root:Epoch = [ 429/3000] TrainLoss = 22.98 TrainTime = 35.2162s
# INFO:root:Epoch = [ 430/3000] TrainLoss = 22.92 TrainTime = 35.2708s
# INFO:root:Epoch = [ 431/3000] TrainLoss = 23.51 TrainTime = 37.3505s
# INFO:root:Epoch = [ 432/3000] TrainLoss = 22.48 TrainTime = 36.1828s
# INFO:root:Epoch = [ 433/3000] TrainLoss = 22.32 TrainTime = 40.5171s
# INFO:root:Epoch = [ 434/3000] TrainLoss = 22.89 TrainTime = 42.8073s
# INFO:root:Epoch = [ 435/3000] TrainLoss = 23.18 TrainTime = 41.3588s
# INFO:root:Epoch = [ 436/3000] TrainLoss = 22.9 TrainTime = 53.4927s
# INFO:root:Epoch = [ 437/3000] TrainLoss = 22.51 TrainTime = 48.5234s
# INFO:root:Epoch = [ 438/3000] TrainLoss = 22.78 TrainTime = 36.8132s
# INFO:root:Epoch = [ 439/3000] TrainLoss = 22.5 TrainTime = 36.6940s
# INFO:root:Epoch = [ 440/3000] TrainLoss = 22.51 TrainTime = 33.4112s
# INFO:root:Epoch = [ 441/3000] TrainLoss = 22.85 TrainTime = 36.1550s
# INFO:root:Epoch = [ 442/3000] TrainLoss = 22.43 TrainTime = 35.7110s
# INFO:root:Epoch = [ 443/3000] TrainLoss = 22.5 TrainTime = 35.2677s
# INFO:root:Epoch = [ 444/3000] TrainLoss = 22.39 TrainTime = 33.1789s
# INFO:root:Epoch = [ 445/3000] TrainLoss = 22.61 TrainTime = 33.8641s
# INFO:root:Epoch = [ 446/3000] TrainLoss = 22.56 TrainTime = 34.8520s
# INFO:root:Epoch = [ 447/3000] TrainLoss = 22.53 TrainTime = 35.4455s
# INFO:root:Epoch = [ 448/3000] TrainLoss = 22.55 TrainTime = 33.3814s
# INFO:root:Epoch = [ 449/3000] TrainLoss = 22.85 TrainTime = 37.4527s
# INFO:root:Epoch = [ 450/3000] TrainLoss = 22.64 TrainTime = 34.3172s
# INFO:root:Epoch = [ 451/3000] TrainLoss = 22.79 TrainTime = 36.7638s
# INFO:root:Epoch = [ 452/3000] TrainLoss = 22.75 TrainTime = 34.4006s
# INFO:root:Epoch = [ 453/3000] TrainLoss = 22.68 TrainTime = 36.8621s
# INFO:root:Epoch = [ 454/3000] TrainLoss = 22.83 TrainTime = 37.0361s
# INFO:root:Epoch = [ 455/3000] TrainLoss = 23.04 TrainTime = 36.3534s
# INFO:root:Epoch = [ 456/3000] TrainLoss = 22.63 TrainTime = 35.1522s
# INFO:root:Epoch = [ 457/3000] TrainLoss = 22.5 TrainTime = 34.7480s
# INFO:root:Epoch = [ 458/3000] TrainLoss = 22.88 TrainTime = 49.7164s
# INFO:root:Epoch = [ 459/3000] TrainLoss = 22.77 TrainTime = 36.2768s
# INFO:root:Epoch = [ 460/3000] TrainLoss = 23.08 TrainTime = 37.8065s
# INFO:root:Epoch = [ 461/3000] TrainLoss = 22.58 TrainTime = 37.1771s
# INFO:root:Epoch = [ 462/3000] TrainLoss = 22.98 TrainTime = 36.8342s
# INFO:root:Epoch = [ 463/3000] TrainLoss = 22.42 TrainTime = 40.9972s
# INFO:root:Epoch = [ 464/3000] TrainLoss = 22.73 TrainTime = 35.8652s
# INFO:root:Epoch = [ 465/3000] TrainLoss = 22.59 TrainTime = 37.6699s
# INFO:root:Epoch = [ 466/3000] TrainLoss = 22.7 TrainTime = 35.3524s
# INFO:root:Epoch = [ 467/3000] TrainLoss = 22.84 TrainTime = 38.4808s
# INFO:root:Epoch = [ 468/3000] TrainLoss = 22.98 TrainTime = 40.3103s
# INFO:root:Epoch = [ 469/3000] TrainLoss = 22.94 TrainTime = 35.2263s
# INFO:root:Epoch = [ 470/3000] TrainLoss = 22.48 TrainTime = 39.0667s
# INFO:root:Epoch = [ 471/3000] TrainLoss = 22.85 TrainTime = 36.9266s
# INFO:root:Epoch = [ 472/3000] TrainLoss = 22.97 TrainTime = 38.0669s
# INFO:root:Epoch = [ 473/3000] TrainLoss = 22.77 TrainTime = 35.9625s
# INFO:root:Epoch = [ 474/3000] TrainLoss = 22.87 TrainTime = 39.3157s
# INFO:root:Epoch = [ 475/3000] TrainLoss = 22.55 TrainTime = 36.1714s
# INFO:root:Epoch = [ 476/3000] TrainLoss = 22.65 TrainTime = 39.7668s
# INFO:root:Epoch = [ 477/3000] TrainLoss = 22.83 TrainTime = 35.1719s
# INFO:root:Epoch = [ 478/3000] TrainLoss = 22.75 TrainTime = 37.3280s
# INFO:root:Epoch = [ 479/3000] TrainLoss = 22.59 TrainTime = 37.5355s
# INFO:root:Epoch = [ 480/3000] TrainLoss = 22.92 TrainTime = 37.9950s
# INFO:root:Epoch = [ 481/3000] TrainLoss = 22.74 TrainTime = 39.7340s
# INFO:root:Epoch = [ 482/3000] TrainLoss = 22.43 TrainTime = 43.3857s
# INFO:root:Epoch = [ 483/3000] TrainLoss = 22.96 TrainTime = 37.8877s
# INFO:root:Epoch = [ 484/3000] TrainLoss = 22.88 TrainTime = 42.1571s
# INFO:root:Epoch = [ 485/3000] TrainLoss = 22.88 TrainTime = 37.9290s
# INFO:root:Epoch = [ 486/3000] TrainLoss = 22.59 TrainTime = 37.0811s
# INFO:root:Epoch = [ 487/3000] TrainLoss = 22.82 TrainTime = 39.1386s
# INFO:root:Epoch = [ 488/3000] TrainLoss = 22.71 TrainTime = 37.2611s
# INFO:root:Epoch = [ 489/3000] TrainLoss = 22.69 TrainTime = 38.6856s
# INFO:root:Epoch = [ 490/3000] TrainLoss = 22.77 TrainTime = 35.6520s
# INFO:root:Epoch = [ 491/3000] TrainLoss = 23.05 TrainTime = 36.8061s
# INFO:root:Epoch = [ 492/3000] TrainLoss = 23.24 TrainTime = 36.5128s
# INFO:root:Epoch = [ 493/3000] TrainLoss = 22.67 TrainTime = 38.2385s
# INFO:root:Epoch = [ 494/3000] TrainLoss = 22.53 TrainTime = 39.1639s
# INFO:root:Epoch = [ 495/3000] TrainLoss = 22.64 TrainTime = 49.3923s
# INFO:root:Epoch = [ 496/3000] TrainLoss = 22.83 TrainTime = 37.3018s
# INFO:root:Epoch = [ 497/3000] TrainLoss = 22.65 TrainTime = 36.7327s
# INFO:root:Epoch = [ 498/3000] TrainLoss = 22.6 TrainTime = 36.6244s
# INFO:root:Epoch = [ 499/3000] TrainLoss = 22.69 TrainTime = 35.7715s
# INFO:root:Epoch = [ 500/3000] TrainLoss = 22.45 TrainTime = 38.3836s
# INFO:root:Epoch = [ 501/3000] TrainLoss = 22.56 TrainTime = 36.4594s
# INFO:root:Epoch = [ 502/3000] TrainLoss = 22.66 TrainTime = 36.8210s
# INFO:root:Epoch = [ 503/3000] TrainLoss = 22.53 TrainTime = 41.4630s
# INFO:root:Epoch = [ 504/3000] TrainLoss = 22.94 TrainTime = 36.7173s
# INFO:root:Epoch = [ 505/3000] TrainLoss = 22.98 TrainTime = 36.3347s
# INFO:root:Epoch = [ 506/3000] TrainLoss = 22.91 TrainTime = 38.4410s
# INFO:root:Epoch = [ 507/3000] TrainLoss = 22.77 TrainTime = 35.9719s
# INFO:root:Epoch = [ 508/3000] TrainLoss = 22.52 TrainTime = 36.2574s
# INFO:root:Epoch = [ 509/3000] TrainLoss = 22.82 TrainTime = 36.2366s
# INFO:root:Epoch = [ 510/3000] TrainLoss = 22.45 TrainTime = 37.1158s
# INFO:root:Epoch = [ 511/3000] TrainLoss = 23 TrainTime = 38.6484s
# INFO:root:Epoch = [ 512/3000] TrainLoss = 22.79 TrainTime = 36.3474s
# INFO:root:Epoch = [ 513/3000] TrainLoss = 22.69 TrainTime = 36.1634s
# INFO:root:Epoch = [ 514/3000] TrainLoss = 22.6 TrainTime = 36.7042s
# INFO:root:Epoch = [ 515/3000] TrainLoss = 22.51 TrainTime = 36.9932s
# INFO:root:Epoch = [ 516/3000] TrainLoss = 22.6 TrainTime = 35.9040s
# INFO:root:Epoch = [ 517/3000] TrainLoss = 22.6 TrainTime = 34.9136s
# INFO:root:Epoch = [ 518/3000] TrainLoss = 22.72 TrainTime = 36.9592s
# INFO:root:Epoch = [ 519/3000] TrainLoss = 22.87 TrainTime = 37.5116s
# INFO:root:Epoch = [ 520/3000] TrainLoss = 22.5 TrainTime = 35.7497s
# INFO:root:Epoch = [ 521/3000] TrainLoss = 22.6 TrainTime = 38.3084s
# INFO:root:Epoch = [ 522/3000] TrainLoss = 22.91 TrainTime = 36.1425s
# INFO:root:Epoch = [ 523/3000] TrainLoss = 22.84 TrainTime = 36.5871s
# INFO:root:Epoch = [ 524/3000] TrainLoss = 22.72 TrainTime = 38.8765s
# INFO:root:Epoch = [ 525/3000] TrainLoss = 22.62 TrainTime = 35.9649s
# INFO:root:Epoch = [ 526/3000] TrainLoss = 22.68 TrainTime = 37.0409s
# INFO:root:Epoch = [ 527/3000] TrainLoss = 22.5 TrainTime = 38.5106s
# INFO:root:Epoch = [ 528/3000] TrainLoss = 22.88 TrainTime = 36.9722s
# INFO:root:Epoch = [ 529/3000] TrainLoss = 23.11 TrainTime = 37.3149s
# INFO:root:Epoch = [ 530/3000] TrainLoss = 22.43 TrainTime = 37.0674s
# INFO:root:Epoch = [ 531/3000] TrainLoss = 22.35 TrainTime = 36.5245s
# INFO:root:Epoch = [ 532/3000] TrainLoss = 22.33 TrainTime = 35.9114s
# INFO:root:Epoch = [ 533/3000] TrainLoss = 22.89 TrainTime = 37.2632s
# INFO:root:Epoch = [ 534/3000] TrainLoss = 22.44 TrainTime = 38.1715s
# INFO:root:Epoch = [ 535/3000] TrainLoss = 22.38 TrainTime = 37.2632s
# INFO:root:Epoch = [ 536/3000] TrainLoss = 22.55 TrainTime = 36.6791s
# INFO:root:Epoch = [ 537/3000] TrainLoss = 22.25 TrainTime = 37.4329s
# INFO:root:Epoch = [ 538/3000] TrainLoss = 22.42 TrainTime = 35.6269s
# INFO:root:Epoch = [ 539/3000] TrainLoss = 23.02 TrainTime = 36.7820s
# INFO:root:Epoch = [ 540/3000] TrainLoss = 22.66 TrainTime = 37.4330s
# INFO:root:Epoch = [ 541/3000] TrainLoss = 22.59 TrainTime = 40.1173s
# INFO:root:Epoch = [ 542/3000] TrainLoss = 22.82 TrainTime = 36.0668s
# INFO:root:Epoch = [ 543/3000] TrainLoss = 22.64 TrainTime = 40.6235s
# INFO:root:Epoch = [ 544/3000] TrainLoss = 22.86 TrainTime = 41.1260s
# INFO:root:Epoch = [ 545/3000] TrainLoss = 22.54 TrainTime = 41.0821s
# INFO:root:Epoch = [ 546/3000] TrainLoss = 22.72 TrainTime = 37.1515s
# INFO:root:Epoch = [ 547/3000] TrainLoss = 22.37 TrainTime = 40.5020s
# INFO:root:Epoch = [ 548/3000] TrainLoss = 23.06 TrainTime = 39.1250s
# INFO:root:Epoch = [ 549/3000] TrainLoss = 22.62 TrainTime = 41.5833s
# INFO:root:Epoch = [ 550/3000] TrainLoss = 22.73 TrainTime = 37.2242s
# INFO:root:Epoch = [ 551/3000] TrainLoss = 22.55 TrainTime = 39.7311s
# INFO:root:Epoch = [ 552/3000] TrainLoss = 22.93 TrainTime = 41.1049s
# INFO:root:Epoch = [ 553/3000] TrainLoss = 22.84 TrainTime = 41.8756s
# INFO:root:Epoch = [ 554/3000] TrainLoss = 22.41 TrainTime = 51.5414s
# INFO:root:Epoch = [ 555/3000] TrainLoss = 22.25 TrainTime = 49.3632s
# INFO:root:Epoch = [ 556/3000] TrainLoss = 22.49 TrainTime = 47.1431s
# INFO:root:Epoch = [ 557/3000] TrainLoss = 22.57 TrainTime = 37.7671s
# INFO:root:Epoch = [ 558/3000] TrainLoss = 23.12 TrainTime = 38.2145s
# INFO:root:Epoch = [ 559/3000] TrainLoss = 22.44 TrainTime = 39.1179s
# INFO:root:Epoch = [ 560/3000] TrainLoss = 22.83 TrainTime = 39.7403s
# INFO:root:Epoch = [ 561/3000] TrainLoss = 23.04 TrainTime = 39.8039s
# INFO:root:Epoch = [ 562/3000] TrainLoss = 22.47 TrainTime = 42.4533s
# INFO:root:Epoch = [ 563/3000] TrainLoss = 22.59 TrainTime = 36.6823s
# INFO:root:Epoch = [ 564/3000] TrainLoss = 22.56 TrainTime = 37.8862s
# INFO:root:Epoch = [ 565/3000] TrainLoss = 22.64 TrainTime = 38.0705s
# INFO:root:Epoch = [ 566/3000] TrainLoss = 22.5 TrainTime = 37.5066s
# INFO:root:Epoch = [ 567/3000] TrainLoss = 22.55 TrainTime = 37.4435s
# INFO:root:Epoch = [ 568/3000] TrainLoss = 22.49 TrainTime = 44.7817s
# INFO:root:Epoch = [ 569/3000] TrainLoss = 22.65 TrainTime = 38.5141s
# INFO:root:Epoch = [ 570/3000] TrainLoss = 22.76 TrainTime = 42.1185s
# INFO:root:Epoch = [ 571/3000] TrainLoss = 22.51 TrainTime = 41.1357s
# INFO:root:Epoch = [ 572/3000] TrainLoss = 22.65 TrainTime = 41.9322s
# INFO:root:Epoch = [ 573/3000] TrainLoss = 22.49 TrainTime = 37.8889s
# INFO:root:Epoch = [ 574/3000] TrainLoss = 22.84 TrainTime = 40.2915s
# INFO:root:Epoch = [ 575/3000] TrainLoss = 22.99 TrainTime = 40.3461s
# INFO:root:Epoch = [ 576/3000] TrainLoss = 22.41 TrainTime = 42.3931s
# INFO:root:Epoch = [ 577/3000] TrainLoss = 22.53 TrainTime = 43.3422s
# INFO:root:Epoch = [ 578/3000] TrainLoss = 22.58 TrainTime = 57.3721s
# INFO:root:Epoch = [ 579/3000] TrainLoss = 22.48 TrainTime = 47.5480s
# INFO:root:Epoch = [ 580/3000] TrainLoss = 22.69 TrainTime = 41.7431s
# INFO:root:Epoch = [ 581/3000] TrainLoss = 22.13 TrainTime = 43.6806s
# INFO:root:Epoch = [ 582/3000] TrainLoss = 22.74 TrainTime = 41.1744s
# INFO:root:Epoch = [ 583/3000] TrainLoss = 22.97 TrainTime = 43.1603s
# INFO:root:Epoch = [ 584/3000] TrainLoss = 22.69 TrainTime = 41.7445s
# INFO:root:Epoch = [ 585/3000] TrainLoss = 22.7 TrainTime = 41.5695s
# INFO:root:Epoch = [ 586/3000] TrainLoss = 22.66 TrainTime = 42.1554s
# INFO:root:Epoch = [ 587/3000] TrainLoss = 22.38 TrainTime = 40.3513s
# INFO:root:Epoch = [ 588/3000] TrainLoss = 22.49 TrainTime = 40.6654s
# INFO:root:Epoch = [ 589/3000] TrainLoss = 22.96 TrainTime = 40.6082s
# INFO:root:Epoch = [ 590/3000] TrainLoss = 22.92 TrainTime = 41.1183s
# INFO:root:Epoch = [ 591/3000] TrainLoss = 22.47 TrainTime = 39.9355s
# INFO:root:Epoch = [ 592/3000] TrainLoss = 22.86 TrainTime = 42.6685s
# INFO:root:Epoch = [ 593/3000] TrainLoss = 22.6 TrainTime = 42.7851s
# INFO:root:Epoch = [ 594/3000] TrainLoss = 23.07 TrainTime = 41.7531s
# INFO:root:Epoch = [ 595/3000] TrainLoss = 22.72 TrainTime = 40.2487s

# %%
import torch.nn as nn
model = torch.load('/home/liu.6221/PnP_fastMRI-master _Liu/190.pt')
def kernel_specnorm(kernel, power_iter=10, print_values=False):
    with torch.no_grad():
        kernel_mat = kernel
        height = kernel_mat.size(0)
        kernel_mat = kernel_mat.reshape(height,-1)

        # Create random U
        u = torch.normal(mean=torch.zeros((height))).to(kernel.device)

        # Perform power iterations
        for iter in range(power_iter):
            Ku = torch.mv(kernel_mat.t(), u)
            v =  Ku / Ku.norm()
            Kv = torch.mv(kernel_mat, v)
            u = Kv / Kv.norm()
            if print_values:
                print(torch.dot(u, torch.mv(kernel_mat, v)))
        return torch.dot(u, torch.mv(kernel_mat, v)).item()


def test_spectral_norm(model, test_type='conv', N=128,power_iter=10, print_values=True):
    # Loop over layers
    a_l = []
    for layer in model.modules():
        if isinstance(layer,nn.Conv2d):
            kernel = layer.weight
            L = kernel_specnorm(kernel, power_iter=power_iter)
            a_l.append(L)
            if print_values:
                print(L)
            
    L_total = np.prod(np.array(a_l))
    if print_values:
        print(L_total)
    return a_l, L_total
                
L = test_spectral_norm(model, power_iter=1000)

# %%
0.1**(1/5)
